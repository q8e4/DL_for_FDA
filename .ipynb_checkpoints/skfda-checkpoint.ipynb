# %% [markdown]
# # Neighbors Scalar Regression
#
# Shows the usage of the nearest neighbors regressor with scalar response.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV, train_test_split

import skfda
from skfda.ml.regression import KNeighborsRegressor

# %%
path = '1st_task/'

# %%
df_X = pd.read_csv(path + "X.csv", header=None)
df_y = pd.read_csv(path + "Y.csv", header=None)

original_grid = np.linspace(0, 47, num=48)
scaled_grid = original_grid / 47.0

# %%
df_y.drop(2646, axis=0, inplace=True)

# %%
df_X.drop(2646, axis=0, inplace=True)

# %%
fd_X = skfda.FDataGrid(
    data_matrix=df_X.iloc[:],
    grid_points=scaled_grid,
)

# %%
X = fd_X.coordinates[0]

# %%
y = np.array(df_y).squeeze()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    random_state=42,
)

# %%
knn = KNeighborsRegressor(weights='distance')
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(weights='distance')

# %%
pred = knn.predict(X_test)
print(pred)
# Out:
# [42.81692787 33.64864109 57.53691259 ... 26.51366554 34.12914459
#  55.35176272]

# %% [markdown]
# The following figure compares the real precipitations with the predicted
# values.

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.scatter(y_test, pred)
ax.plot(y_test, y_test)
ax.set_xlabel("Truth")
ax.set_ylabel("Prediction")
# Out:
# Text(0, 0.5, 'Prediction')

# %%
score = knn.score(X_test, y_test)
print(score)
# Out:
#   Cell In[18], line 1
#     score = knn.scoring.mean_squared_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average', squared=True)
#                                            ^
# SyntaxError: iterable argument unpacking follows keyword argument unpacking

# %%
param_grid = {
    'n_neighbors': range(1, 12, 2),
    'weights': ['uniform', 'distance'],
}


knn = KNeighborsRegressor()
gscv = GridSearchCV(
    knn,
    param_grid,
    cv=5,
)
gscv.fit(X, y)
# Out:
# /home/kaliyev/.local/lib/python3.11/site-packages/numpy/ma/core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': range(1, 12, 2),
#                          'weights': ['uniform', 'distance']})

# %%
print("Best params", gscv.best_params_)
print("Best score", gscv.best_score_)
# Out:
# Best params {'n_neighbors': 11, 'weights': 'distance'}
# Best score 0.9148144010245176
